# %%
import os
from dotenv import load_dotenv
from pyprojroot import here
from typing import List
from langchain_community.utilities import SQLDatabase
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnablePassthrough
from langchain.chains import create_sql_query_chain
from operator import itemgetter
from pprint import pprint

load_dotenv()
# Out:
# True

# %%
os.environ['OPENAI_API_KEY'] = os.getenv("OPEN_AI_API_KEY")

sql_agent_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
# Connect to database
sqldb_directory = here("data/csv_sql.db")
db = SQLDatabase.from_uri(f"sqlite:///{sqldb_directory}")
print("Database dialect:", db.dialect)
print("Available tables:", db.get_usable_table_names())

# Get table schema information for better context
table_info = db.get_table_info()
print("\nTable schema information:")
# Out:
# Database dialect: sqlite
# Available tables: ['cluster_data']
#
# Table schema information:

# %%
class SingleTableSQLAgent:
    """
    A specialized SQL agent for querying a single large table in a SQL database.
    
    This agent is optimized for scenarios where you have one large table and need
    to generate efficient SQL queries based on natural language questions.
    
    Attributes:
        sql_agent_llm (ChatOpenAI): The language model for SQL generation
        db (SQLDatabase): The SQL database connection
        query_chain (Runnable): Chain for generating SQL queries
    """
    
    def __init__(self, sqldb_directory: str, llm_model: str = "gpt-4o-mini", llm_temperature: float = 0):
        """
        Initialize the SingleTableSQLAgent.
        
        Args:
            sqldb_directory (str): Path to the SQLite database file
            llm_model (str): The LLM model to use
            llm_temperature (float): Temperature for LLM responses
        """
        self.sql_agent_llm = ChatOpenAI(model=llm_model, temperature=llm_temperature)
        self.db = SQLDatabase.from_uri(f"sqlite:///{sqldb_directory}")
        
        # Since we have only one table, we can directly create the query chain
        # with enhanced context about the table structure
        self.query_chain = create_sql_query_chain(self.sql_agent_llm, self.db)
        
        # Get table information for better context
        self.table_info = self.db.get_table_info()
        print(f"Connected to database with table: {self.db.get_usable_table_names()}")
    
    def query(self, question: str) -> str:
        """
        Execute a natural language query against the database.
        
        Args:
            question (str): Natural language question about the data
            
        Returns:
            str: SQL query result
        """
        try:
            # Generate SQL query
            raw_sql_query = self.query_chain.invoke({"question": question})
            
            # Clean the SQL query by removing any prefixes like "SQLQuery: "
            sql_query = self._clean_sql_query(raw_sql_query)
            print(f"Generated SQL Query:\n{sql_query}")
            
            # Execute query
            result = self.db.run(sql_query)
            return result
            
        except Exception as e:
            return f"Error executing query: {str(e)}"
    
    def _clean_sql_query(self, raw_query: str) -> str:
        """
        Clean the SQL query by removing any prefixes or formatting artifacts.
        
        Args:
            raw_query (str): Raw SQL query from the LLM
            
        Returns:
            str: Cleaned SQL query
        """
        # Remove common prefixes that LLMs might add
        prefixes_to_remove = [
            "SQLQuery: ",
            "SQL Query: ",
            "Query: ",
            "SQL: ",
            "```sql\n",
            "```\n",
            "sql\n"
        ]
        
        cleaned_query = raw_query.strip()
        
        for prefix in prefixes_to_remove:
            if cleaned_query.startswith(prefix):
                cleaned_query = cleaned_query[len(prefix):].strip()
        
        # Remove trailing backticks if present
        if cleaned_query.endswith("```"):
            cleaned_query = cleaned_query[:-3].strip()
        
        return cleaned_query
    
    def get_sample_data(self, limit: int = 5) -> str:
        """
        Get sample data from the table to understand its structure.
        
        Args:
            limit (int): Number of sample rows to return
            
        Returns:
            str: Sample data from the table
        """
        table_name = self.db.get_usable_table_names()[0]
        query = f"SELECT * FROM {table_name} LIMIT {limit};"
        return self.db.run(query)
    
    def get_column_info(self) -> str:
        """
        Get detailed information about the table columns.
        
        Returns:
            str: Column information
        """
        table_name = self.db.get_usable_table_names()[0]
        # Get column info using PRAGMA (SQLite specific)
        query = f"PRAGMA table_info({table_name});"
        return self.db.run(query)
    
    def get_table_stats(self) -> dict:
        """
        Get basic statistics about the table.
        
        Returns:
            dict: Table statistics including row count
        """
        table_name = self.db.get_usable_table_names()[0]
        
        # Get row count
        count_query = f"SELECT COUNT(*) as total_rows FROM {table_name};"
        row_count = self.db.run(count_query)
        
        return {
            "table_name": table_name,
            "total_rows": row_count,
            "column_info": self.get_column_info()
        }

# %%
# Initialize the agent
agent = SingleTableSQLAgent(
    sqldb_directory=sqldb_directory,
    llm_model="gpt-4o-mini",
    llm_temperature=0
)
# Out:
# Connected to database with table: ['cluster_data']

# %%
# Example usage
if __name__ == "__main__":
    # Get basic table information
    print("\n" + "="*50)
    print("TABLE STATISTICS")
    print("="*50)
    stats = agent.get_table_stats()
    pprint(stats)
    
    # Get sample data
    print("\n" + "="*50)
    print("SAMPLE DATA")
    print("="*50)
    sample_data = agent.get_sample_data(limit=3)
    print(sample_data)
    
    # Example queries
    print("\n" + "="*50)
    print("EXAMPLE QUERIES")
    print("="*50)
    
    # Query 1: Count records
    print("\nQuery 1: How many records are in the database?")
    result1 = agent.query("How many records are in the database?")
    print(f"Result: {result1}")
    
    # Query 2: Unique values in a specific column (adjust based on your data)
    print("\nQuery 2: How many unique clusters are there?")
    result2 = agent.query("How many unique clusters are there in the data?")
    print(f"Result: {result2}")
    
    # Query 3: Filter and count (adjust based on your data structure)
    print("\nQuery 3: Count records by status")
    result3 = agent.query("Show me the count of records grouped by status")
    print(f"Result: {result3}")
# Out:
# ==================================================
# TABLE STATISTICS
# ==================================================
# {'column_info': "[(0, 'ALERT_ID', 'TEXT', 0, None, 0), (1, 'CUSTOMER_ID', "
#                 "'REAL', 0, None, 0), (2, 'PROJECT_ID', 'REAL', 0, None, 0), "
#                 "(3, 'SUBSCRIPTION_ID', 'REAL', 0, None, 0), (4, "
#                 "'RESOURCE_ID', 'REAL', 0, None, 0), (5, 'RESOURCE_TYPE', "
#                 "'REAL', 0, None, 0), (6, 'AGENT_ID', 'TEXT', 0, None, 0), (7, "
#                 "'PLUGIN_NAME', 'TEXT', 0, None, 0), (8, 'ALERT_TYPE', 'TEXT', "
#                 "0, None, 0), (9, 'PLUGIN_TYPE', 'TEXT', 0, None, 0), (10, "
#                 "'PLUGIN_SUBTYPE', 'TEXT', 0, None, 0), (11, 'TITLE', 'TEXT', "
#                 "0, None, 0), (12, 'DESCRIPTION', 'TEXT', 0, None, 0), (13, "
#                 "'SEVERITY', 'TEXT', 0, None, 0), (14, 'VALUE_LABELS', 'TEXT', "
#                 "0, None, 0), (15, 'THRESHOLD_EXPRESSION', 'TEXT', 0, None, "
#                 "0), (16, 'RULE_ID', 'REAL', 0, None, 0), (17, 'PLUGIN_ID', "
#                 "'REAL', 0, None, 0), (18, 'IPADDRESS', 'TEXT', 0, None, 0), "
#                 "(19, 'HOSTNAME', 'TEXT', 0, None, 0), (20, 'CREATED_ON', "
#                 "'TEXT', 0, None, 0), (21, 'UPDATED_ON', 'TEXT', 0, None, 0), "
#                 "(22, 'CLOSED_ON', 'TEXT', 0, None, 0), (23, 'STATE', 'TEXT', "
#                 "0, None, 0), (24, 'OCCURRENCE_COUNT', 'INTEGER', 0, None, 0), "
#                 "(25, 'INSERT_ON', 'TEXT', 0, None, 0), (26, 'INSERT_BY', "
#                 "'TEXT', 0, None, 0), (27, 'ACK_TIME', 'TEXT', 0, None, 0), "
#                 "(28, 'ACK_BY', 'TEXT', 0, None, 0), (29, 'ACK_ID', 'TEXT', 0, "
#                 "None, 0), (30, 'LAST_UPDATE_TIME', 'TEXT', 0, None, 0), (31, "
#                 "'LAST_UPDATE_BY', 'TEXT', 0, None, 0), (32, 'STATUS', 'TEXT', "
#                 "0, None, 0), (33, 'VALUE', 'TEXT', 0, None, 0), (34, "
#                 "'LAST_UPDATE_CATEGORY', 'TEXT', 0, None, 0), (35, "
#                 "'HIERACHY_MAP_ID', 'REAL', 0, None, 0), (36, 'CLOSURE_TIME', "
#                 "'REAL', 0, None, 0), (37, 'METRIC_ID', 'REAL', 0, None, 0), "
#                 "(38, 'ASSETID', 'REAL', 0, None, 0), (39, 'ENVIORMENT', "
#                 "'TEXT', 0, None, 0), (40, 'ASSET_TYPE', 'REAL', 0, None, 0), "
#                 "(41, 'HIERARCHY_NAME', 'TEXT', 0, None, 0), (42, "
#                 "'TECHNOLOGY_CATEGORY', 'TEXT', 0, None, 0), (43, "
#                 "'TECHNOLOGY_NAME', 'TEXT', 0, None, 0), (44, 'METRIC_NAME', "
#                 "'TEXT', 0, None, 0), (45, 'COLLABORATION_FLAG', 'TEXT', 0, "
#                 "None, 0), (46, 'INSTANCE_ID', 'REAL', 0, None, 0), (47, "
#                 "'DESCRIPTOR_ID', 'REAL', 0, None, 0), (48, 'DESCRIPTOR_NAME', "
#                 "'TEXT', 0, None, 0), (49, 'MASTER_ALERT_ID', 'TEXT', 0, None, "
#                 "0), (50, 'ALERT_UUID', 'TEXT', 0, None, 0), (51, 'ETA_DATE', "
#                 "'TEXT', 0, None, 0), (52, 'RACI', 'TEXT', 0, None, 0), (53, "
#                 "'ESCALATION_LEVEL', 'REAL', 0, None, 0), (54, "
#                 "'ESCALATION_SLA', 'TEXT', 0, None, 0), (55, 'CLOSED_SLA', "
#                 "'TEXT', 0, None, 0), (56, 'R_UUID', 'TEXT', 0, None, 0), (57, "
#                 "'ALERT_IMPACT', 'REAL', 0, None, 0), (58, 'RECORDID', 'REAL', "
#                 "0, None, 0), (59, 'SERVICE', 'TEXT', 0, None, 0), (60, "
#                 "'PURPOSE', 'REAL', 0, None, 0), (61, 'ALERT_TEMP1', 'REAL', "
#                 "0, None, 0), (62, 'COMPONENT_TYPE', 'REAL', 0, None, 0), (63, "
#                 "'COMPONENT_NAME', 'REAL', 0, None, 0), (64, 'COMPONENT_IP', "
#                 "'REAL', 0, None, 0), (65, 'FEEDBACK', 'REAL', 0, None, 0), "
#                 "(66, 'HASH_KEY', 'TEXT', 0, None, 0), (67, 'ESCALATION_ROLE', "
#                 "'REAL', 0, None, 0), (68, 'WAR_ROOM_NOTIFIED', 'TEXT', 0, "
#                 "None, 0), (69, 'IS_IMPACT', 'TEXT', 0, None, 0), (70, "
#                 "'PRODUCT_CATEGORY', 'TEXT', 0, None, 0), (71, "
#                 "'description_1', 'TEXT', 0, None, 0), (72, 'title_1', 'TEXT', "
#                 "0, None, 0), (73, 'kpiName', 'TEXT', 0, None, 0), (74, "
#                 "'alert_type_1', 'TEXT', 0, None, 0), (75, 'ip_address', "
#                 "'TEXT', 0, None, 0), (76, 'service_name', 'REAL', 0, None, "
#                 "0), (77, 'clean_description', 'TEXT', 0, None, 0), (78, "
#                 "'enhanced_cluster_id', 'INTEGER', 0, None, 0), (79, "
#                 "'enhanced_cluster_name', 'TEXT', 0, None, 0)]",
#  'table_name': 'cluster_data',
#  'total_rows': '[(10000,)]'}
#
# ==================================================
# SAMPLE DATA
# ==================================================
# [('20250515172108410362', 636.0, 132408.0, 13013.0, 202109063589860.0, 4844.0, None, None, 'Exception', '1', '2', 'Hardware_Event_Warning-1', '  Overall security state of the system is at risk.  | 56.4.56.147', 'Warning', '1', None, None, None, '56.4.55.146', 'ap3ib01201', '2025-09-14 18:03:00', '2025-09-14 18:14:00', '2025-01-11 19:15:00', 'Close', 2, '2025-01-11 01:00:57', None, None, None, None, '2025-01-11 19:23:54', None, 'Close', '1', None, 13547.0, None, None, 2.0231206002847376e+16, 'Production', None, 'IMS-CFX', 'Operating System', 'Centos', 'Hardware_Event_Warning', None, 455365.0, None, None, None, 'ALT2025011156627717', None, '{"A":[13547],"R":[13547],"I":[]}', None, None, None, '27216', None, None, None, None, None, None, None, None, None, None, None, 'N', 'N', 'NextGenOps', '  Overall security state of the system is at risk.  | 56.4.56.147', 'Hardware_Event_Warning-1', 'Centos', 'Hardware_Event_Warning', '56.4.56.147', None, 'overall security state of the system is at risk ip_address', 0, 'Cluster_0'), ('20250519142109368465', 636.0, 132408.0, 13013.0, 202109063589860.0, 4844.0, None, None, 'Exception', '1', '2', 'Hardware_Event_Warning-1', '  Overall security state of the system is at risk.  | 56.4.56.147', 'Warning', '1', None, None, None, '56.4.55.146', 'ap3ib01201', '2025-09-14 18:03:00', '2025-09-14 18:14:00', '2025-01-11 19:15:00', 'Close', 2, '2025-01-11 01:00:57', None, None, None, None, '2025-01-11 19:23:54', None, 'Close', '1', None, 13547.0, None, None, 2.0231206002847376e+16, 'Production', None, 'IMS-CFX', 'Operating System', 'Centos', 'Hardware_Event_Warning', None, 455365.0, None, None, None, 'ALT2025011156627717', None, '{"A":[13547],"R":[13547],"I":[]}', None, None, None, '27216', None, None, None, None, None, None, None, None, None, None, None, 'N', 'N', 'NextGenOps', '  Overall security state of the system is at risk.  | 56.4.56.147', 'Hardware_Event_Warning-1', 'Centos', 'Hardware_Event_Warning', '56.4.56.147', None, 'overall security state of the system is at risk ip_address', 0, 'Cluster_0'), ('20250508102107835095', 636.0, 132408.0, 13013.0, 202109063589860.0, 4844.0, None, None, 'Exception', None, None, 'Hardware_Event_Warning-1', '  Overall security state of the system is at risk.  | 56.4.56.147', 'Warning', '1', None, None, None, '56.4.55.146', 'ap3ib01201', '2025-09-14 18:03:00', '2025-09-14 18:14:00', '2025-01-11 19:15:00', 'Close', 2, '2025-01-11 01:00:57', None, None, None, None, '2025-01-11 19:23:54', None, 'Close', '1', None, 13547.0, None, None, 2.0231206002847376e+16, 'Production', None, 'IMS-CFX', 'Operating System', 'Centos', 'Hardware_Event_Warning', None, 2455365.0, None, None, None, 'ALT2025011156627717', None, '{"A":[13547],"R":[13547],"I":[]}', None, None, None, '27216', None, None, None, None, None, None, None, None, None, None, None, 'N', 'N', 'NextGenOps', '  Overall security state of the system is at risk.  | 56.4.56.147', 'Hardware_Event_Warning-1', 'Centos', 'Hardware_Event_Warning', '56.4.56.147', None, 'overall security state of the system is at risk ip_address', 0, 'Cluster_0')]
#
# ==================================================
# EXAMPLE QUERIES
# ==================================================
#
# Query 1: How many records are in the database?
# Generated SQL Query:
# SELECT COUNT(*) AS "record_count" FROM cluster_data;
# Result: [(10000,)]
#
# Query 2: How many unique clusters are there?
# Generated SQL Query:
# SELECT COUNT(DISTINCT "enhanced_cluster_name") AS unique_clusters
# FROM cluster_data;
# Result: [(59,)]
#
# Query 3: Count records by status
# Generated SQL Query:
# SELECT "STATUS", COUNT(*) AS "COUNT"
# FROM cluster_data
# GROUP BY "STATUS"
# LIMIT 5;
# Result: [('A', 26), ('Close', 9974)]

# %%
# Tool function for use in agent frameworks
def query_single_table_db(query: str) -> str:
    """
    Tool function to query the single table database.
    
    Args:
        query (str): Natural language query
        
    Returns:
        str: Query result
    """
    agent = SingleTableSQLAgent(
        sqldb_directory=sqldb_directory,
        llm_model="gpt-4o-mini",
        llm_temperature=0
    )
    return agent.query(query)
